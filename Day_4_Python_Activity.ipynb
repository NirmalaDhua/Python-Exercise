# %% [markdown]
# # Pandas, Matplotlib and Seaborn

# %%
import pandas as pd

# %% [markdown]
# [Dataset Soruce](https://www.kaggle.com/datasets/rajkumarpandey02/gdp-in-usd-per-capita-income-by-country)

# %% [markdown]
# CONTENT
# <p>The figures presented here do not take into account differences in the cost of living in different countries, and the results vary greatly from one year to another based on fluctuations in the exchange rates of the country's currency. Such fluctuations change a country's ranking from one year to the next, even though they often make little or no difference to the standard of living of its population.
#
# GDP per capita is often considered an indicator of a country's standard of living; however, this is inaccurate because GDP per capita is not a measure of personal income.
#
# Comparisons of national income are also frequently made on the basis of purchasing power parity (PPP), to adjust for differences in the cost of living in different countries. (See List of countries by GDP (PPP) per capita.) PPP largely removes the exchange rate problem but not others; it does not reflect the value of economic output in international trade, and it also requires more estimation than GDP per capita. On the whole, PPP per capita figures are more narrowly spread than nominal GDP per capita figures.</p>

# %% [markdown]
# Here are some resources to learn about GDP:
# #### [World Bank](https://data.worldbank.org/indicator/ny.gdp.pcap.cd?most_recent_value_desc=false)
# #### [Our World in Data](https://ourworldindata.org/grapher/gdp-per-capita-worldbank)
# #### [IMF](https://www.imf.org/external/datamapper/NGDPD@WEO/OEMDC/ADVEC/WEOWORLD)
# #### [UN Data](https://data.un.org/Data.aspx?d=SNAAMA&f=grID%3A101%3BcurrID%3AUSD%3BpcFlag%3A1)

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/GDP (nominal) per Capita (1).csv", encoding= 'unicode_escape',  index_col=0)

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Use this section to explore and inspect dataset.

# %%
df.shape
# Out:
# (223, 8)

# %%
df.head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe             0         0              234316
# 2     Liechtenstein    Europe             0         0              157755
# 3        Luxembourg    Europe        132372      2023              133590
# 4           Ireland    Europe        114581      2023              100172
# 5           Bermuda  Americas             0         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %%
df.tail()
# Out:
#     Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 219            Malawi    Africa           496      2023                 635
# 220       South Sudan    Africa           467      2023                1072
# 221      Sierra Leone    Africa           415      2023                 480
# 222       Afghanistan      Asia           611      2020                 369
# 223           Burundi    Africa           249      2023                 222
#
#      WorldBank_Year  UN_Estimate UN_Year
# 219            2021          613    2021
# 220            2015          400    2021
# 221            2021          505    2021
# 222            2021          373    2021
# 223            2021          311    2021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 223 entries, 1 to 223
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country/Territory   223 non-null    object
#  1   UN_Region           223 non-null    object
#  2   IMF_Estimate        223 non-null    int64
#  3   IMF_Year            223 non-null    int64
#  4   WorldBank_Estimate  223 non-null    int64
#  5   WorldBank_Year      223 non-null    int64
#  6   UN_Estimate         223 non-null    int64
#  7   UN_Year             223 non-null    object
# dtypes: int64(5), object(3)
# memory usage: 15.7+ KB

# %%
df.describe()
# Out:
#         IMF_Estimate     IMF_Year  WorldBank_Estimate  WorldBank_Year  \
# count     223.000000   223.000000          223.000000      223.000000
# mean    15351.632287  1787.098655        18927.417040     1957.278027
# std     22550.899445   650.695912        29103.564915      353.145867
# min         0.000000     0.000000            0.000000        0.000000
# 25%      1406.500000  2023.000000         2273.500000     2021.000000
# 50%      5421.000000  2023.000000         6805.000000     2021.000000
# 75%     19697.000000  2023.000000        23715.000000     2021.000000
# max    132372.000000  2023.000000       234316.000000     2021.000000
#
#          UN_Estimate
# count     223.000000
# mean    17767.304933
# std     28698.104167
# min         0.000000
# 25%      2039.000000
# 50%      6396.000000
# 75%     20740.000000
# max    234317.000000

# %%
df['IMF_Estimate'].unique()
# Out:
# array([     0, 132372, 114581, 101103,  98767,  91100,  83891,  80034,
#         75180,  68827,  64964,  61098,  56802,  55535,  55395,  54351,
#         53377,  52949,  52722,  52429,  51383,  50571,  49451,  48826,
#         46371,  44408,  44387,  39940,  38567,  36989,  36812,  35458,
#         35385,  35103,  33907,  33807,  33646,  33393,  33094,  32214,
#         31368,  31223,  31209,  29922,  28385,  28094,  26012,  25136,
#         23457,  22595,  21960,  21677,  21085,  20539,  20537,  19912,
#         19858,  19536,  19385,  18530,  18244,  17856,  17827,  17626,
#         17350,  14893,  14804,  14733,  14403,  13721,  13709,  13440,
#         13382,  13065,  12673,  12306,  12264,  11931,  11825,  11548,
#         11308,  11289,  11137,  10849,   9777,   9673,   9359,   9294,
#          9144,   8223,   8181,   8007,   7944,   7772,   7600,   7384,
#          7270,   7058,   7017,   6763,   6757,   6642,   6485,   6417,
#          6342,   6282,   6180,   6007,   5887,   5667,   5641,   5556,
#          5421,   5358,   5308,   5164,   5100,   5048,   5016,   4814,
#          4654,   4481,   4475,   4436,   4336,   4278,   4251,   4146,
#          3589,   4071,   3905,   3802,   3800,   3748,   3644,   3640,
#          3517,   3506,   3497,   3362,   3278,   3204,   3188,   2695,
#          2646,   2601,   2589,   2584,   2563,   2475,   2469,   2299,
#          2280,   2269,   2173,   2024,   1989,   1896,   1858,   1851,
#          1736,   1719,   1699,   1658,   1549,   1475,   1425,   1423,
#          1390,   1377,   1360,   1348,   1277,   1208,   1180,   1105,
#           990,    975,    974,    970,    900,    889,    861,    805,
#           715,    695,    667,    613,    587,    573,    544,    536,
#           534,    496,    467,    415,    611,    249])

# %%
df['IMF_Estimate'].value_counts()
# Out:
# IMF_Estimate
# 0        26
# 4336      1
# 4251      1
# 4146      1
# 3589      1
#          ..
# 14403     1
# 13721     1
# 13709     1
# 13440     1
# 249       1
# Name: count, Length: 198, dtype: int64

# %%
# number of countries per region

# %%
region_counts = df['UN_Region'].value_counts()
print(region_counts)
# Out:
# UN_Region
# Africa      55
# Asia        51
# Europe      48
# Americas    48
# Oceania     20
# World        1
# Name: count, dtype: int64

# %%
#What is European Union[n 1]?

# %%
eu_rows = df[df['UN_Region'] == "European Union[n 1]"]

# Display the filtered rows
print(eu_rows)
# Out:
# Empty DataFrame
# Columns: [Country/Territory, UN_Region, IMF_Estimate, IMF_Year, WorldBank_Estimate, WorldBank_Year, UN_Estimate, UN_Year]
# Index: []

# %%
# Countries in Europe below avarege

# %%
europe_df = df[df['UN_Region'] == 'Europe']

# Calculate the average GDP for Europe (using 'WorldBank_Estimate' as an example)
average_gdp_europe = europe_df['WorldBank_Estimate'].mean()

# Filter for countries below the average
below_average_countries = europe_df[europe_df['WorldBank_Estimate'] < average_gdp_europe]

# Display the results
print(below_average_countries[['Country/Territory', 'WorldBank_Estimate']])
# Out:
#           Country/Territory  WorldBank_Estimate
# 34                   France               43659
# 35                  Andorra               42137
# 36      European Union[n 1]               38411
# 40                    Malta               33487
# 41                    Italy               35658
# 51                 Slovenia               29291
# 52           Czech Republic               26821
# 53                    Spain               30104
# 54                  Estonia               27944
# 57                Lithuania               23723
# 59                 Portugal               24568
# 60                   Latvia               21148
# 62                 Slovakia               21392
# 63                   Greece               20193
# 70                  Croatia               17685
# 72                   Poland               18000
# 75                  Hungary               18728
# 78                  Romania               14858
# 87                 Bulgaria               12222
# 90                   Russia               12195
# 103              Montenegro                9466
# 106                  Serbia                9230
# 112  Bosnia and Herzegovina                7143
# 115                 Belarus                7302
# 118         North Macedonia                6695
# 120                 Albania                6493
# 127                 Moldova                5231
# 133                  Kosovo                5270
# 143                 Ukraine                4836

# %%
## Which countries in Europe has higher GDP than UK?

# %%
europe_df = df[df['UN_Region'] == 'Europe']

# Get the UK's GDP
uk_gdp = europe_df[europe_df['Country/Territory'] == 'United Kingdom']['WorldBank_Estimate'].values[0]

# Filter for countries with higher GDP than the UK
higher_gdp_countries = europe_df[europe_df['WorldBank_Estimate'] > uk_gdp]

# Display the results
print(higher_gdp_countries[['Country/Territory', 'WorldBank_Estimate']])
# Out:
#    Country/Territory  WorldBank_Estimate
# 1             Monaco              234316
# 2      Liechtenstein              157755
# 3         Luxembourg              133590
# 4            Ireland              100172
# 6             Norway               89154
# 7        Switzerland               91992
# 9        Isle of Man               87158
# 13           Iceland               68728
# 14   Channel Islands               75153
# 15     Faroe Islands               69010
# 16           Denmark               68008
# 18       Netherlands               57768
# 20           Austria               53638
# 22            Sweden               61029
# 23           Finland               53655
# 24           Belgium               51247
# 28           Germany               51204

# %% [markdown]
# ## groupby()

# %% [markdown]
# [Learn more about groupby](https://www.geeksforgeeks.org/pandas-groupby/)

# %%
# Group the dataframe by 'UN_Region' and calculate the average GDP for each region
region_gdp = df.groupby('UN_Region')['WorldBank_Estimate'].mean()

# Display the results
print(region_gdp)
# Out:
# UN_Region
# Africa       2470.836364
# Americas    18565.125000
# Asia        13921.313725
# Europe      45193.687500
# Oceania     15113.650000
# World       12235.000000
# Name: WorldBank_Estimate, dtype: float64

# %% [markdown]
# ## Which countries below average by IMF world estimate?

# %%
avg_imf_estimate = df['IMF_Estimate'].mean()
below_avg_countries = df[df['IMF_Estimate'] < avg_imf_estimate]
print(below_avg_countries[['Country/Territory', 'IMF_Estimate']])
# Out:
#     Country/Territory  IMF_Estimate
# 1              Monaco             0
# 2       Liechtenstein             0
# 5             Bermuda             0
# 9         Isle of Man             0
# 10     Cayman Islands             0
# ..                ...           ...
# 219            Malawi           496
# 220       South Sudan           467
# 221      Sierra Leone           415
# 222       Afghanistan           611
# 223           Burundi           249
#
# [159 rows x 2 columns]

# %% [markdown]
# ### IMF estimate 0 values

# %% [markdown]
# ## Which country has highest UN Estimate?

# %%
highest_un_estimate_country = df.loc[df['UN_Estimate'].idxmax(), 'Country/Territory']

print(f"The country with the highest UN Estimate is: {highest_un_estimate_country}")
# Out:
# The country with the highest UN Estimate is: Monaco

# %% [markdown]
# ## Which country has highest Worlbank Estimate?

# %%
highest_worldbank_estimate_country = df.loc[df['WorldBank_Estimate'].idxmax(), 'Country/Territory']

print(f"The country with the highest Worldbank Estimate is: {highest_worldbank_estimate_country}")
# Out:
# The country with the highest Worldbank Estimate is: Monaco

# %% [markdown]
# ## Which country has highest IMF Estimate?

# %%
highest_imf_estimate_country = df.loc[df['IMF_Estimate'].idxmax(), 'Country/Territory']

print(f"The country with the highest IMF Estimate is: {highest_imf_estimate_country}")
# Out:
# The country with the highest IMF Estimate is: Luxembourg

# %% [markdown]
# ## Filling 0 Values by average

# %%
import numpy as np

# %%
# replace 0 with null values

# %%
df['IMF_Estimate'] = df['IMF_Estimate'].replace(0, np.nan)

# %%
# Calculate the average of 'Worldbank_Estimate' and 'UN_Estimate' columns
df['avg_worldbank_un'] = (df['WorldBank_Estimate'] + df['UN_Estimate']) / 2

# %%
# Fill the null values in 'imf' column with the calculated average
df['IMF_Estimate'] = df['IMF_Estimate'].fillna(df['avg_worldbank_un'])

# %%
# Drop the temporary 'avg_worldbank_un' column if not needed

# %%
df = df.drop(columns=['avg_worldbank_un'])

# %% [markdown]
# [Visit this link to learn more about ffill](https://www.w3schools.com/python/pandas/ref_df_ffill.asp)

# %% [markdown]
# [Visit this link to learn more about bfill](https://www.w3schools.com/python/pandas/ref_df_bfill.asp)

# %% [markdown]
# ## Checking Missing Values

# %%
missing_values = df.isnull().sum()

# Print the results
print(missing_values)

# You can also get the total number of missing values in the entire DataFrame:
total_missing = df.isnull().sum().sum()
print(f"\nTotal missing values in the DataFrame: {total_missing}")
# Out:
# Country/Territory     0
# UN_Region             0
# IMF_Estimate          0
# IMF_Year              0
# WorldBank_Estimate    0
# WorldBank_Year        0
# UN_Estimate           0
# UN_Year               0
# dtype: int64
#
# Total missing values in the DataFrame: 0

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Histogram

# %%
df.hist(figsize=(10,8))
plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(figsize=(12,9))

plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=5, figsize=(12,9))

plt.show()

# %%
df["WorldBank_Estimate"].agg(["min","max"])
# Out:
# min         0
# max    234316
# Name: WorldBank_Estimate, dtype: int64

# %%
234316/5
#1 bin size if bins=5
# Out:
# 46863.2

# %%
df[df["WorldBank_Estimate"]<=46863.2]["WorldBank_Estimate"].count()
# Out:
# 195

# %%
234316/10
#1 bin size if bins not given any number
# Out:
# 23431.6

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=3, figsize=(12,9))

plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=15, figsize=(15,12))

#23400/15 = 15300
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()
# Out:
#                     IMF_Estimate  UN_Estimate  WorldBank_Estimate
# IMF_Estimate            1.000000     0.976263            0.974294
# UN_Estimate             0.976263     1.000000            0.930331
# WorldBank_Estimate      0.974294     0.930331            1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['IMF_Estimate'].plot(kind='hist', bins=20, title='IMF_Estimate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['UN_Estimate'].plot(kind='hist', bins=20, title='UN_Estimate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['WorldBank_Estimate'].plot(kind='hist', bins=20, title='WorldBank_Estimate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='IMF_Estimate', y='UN_Estimate', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='UN_Estimate', y='WorldBank_Estimate', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['IMF_Estimate'].plot(kind='line', figsize=(8, 4), title='IMF_Estimate')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['UN_Estimate'].plot(kind='line', figsize=(8, 4), title='UN_Estimate')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['WorldBank_Estimate'].plot(kind='line', figsize=(8, 4), title='WorldBank_Estimate')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))
sns.heatmap(corr)

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True)

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, fmt=".2f", cmap = 'GnBu', annot_kws={"size": 12})

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, cmap = 'Purples')

plt.title("Correlation Map")


plt.show()

# %%
corr = df.select_dtypes(include=[int, float]).corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, cmap = 'Purples')

plt.show()

# %% [markdown]
# ### Bar plot

# %%
df.head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5         0              234316
# 2     Liechtenstein    Europe      163507.5         0              157755
# 3        Luxembourg    Europe      132372.0      2023              133590
# 4           Ireland    Europe      114581.0      2023              100172
# 5           Bermuda  Americas      113371.5         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['IMF_Estimate'].plot(kind='hist', bins=20, title='IMF_Estimate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['IMF_Year'].plot(kind='hist', bins=20, title='IMF_Year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['WorldBank_Estimate'].plot(kind='hist', bins=20, title='WorldBank_Estimate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['WorldBank_Year'].plot(kind='hist', bins=20, title='WorldBank_Year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_12.groupby('Country/Territory').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_13.groupby('UN_Region').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14.plot(kind='scatter', x='IMF_Estimate', y='IMF_Year', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15.plot(kind='scatter', x='IMF_Year', y='WorldBank_Estimate', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16.plot(kind='scatter', x='WorldBank_Estimate', y='WorldBank_Year', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17.plot(kind='scatter', x='WorldBank_Year', y='UN_Estimate', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_18['IMF_Estimate'].plot(kind='line', figsize=(8, 4), title='IMF_Estimate')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['IMF_Year'].plot(kind='line', figsize=(8, 4), title='IMF_Year')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_20['WorldBank_Estimate'].plot(kind='line', figsize=(8, 4), title='WorldBank_Estimate')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21['WorldBank_Year'].plot(kind='line', figsize=(8, 4), title='WorldBank_Year')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['UN_Region'].value_counts()
#     for x_label, grp in _df_22.groupby('Country/Territory')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Country/Territory')
# _ = plt.ylabel('UN_Region')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_23['Country/Territory'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_23, x='IMF_Estimate', y='Country/Territory', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_24['UN_Region'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_24, x='IMF_Estimate', y='UN_Region', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_25['Country/Territory'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_25, x='IMF_Year', y='Country/Territory', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_26['UN_Region'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_26, x='IMF_Year', y='UN_Region', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
sns.barplot(x="UN_Region", y="WorldBank_Estimate", data=df, errorbar=None)

plt.show()

# %%
sns.barplot(x="WorldBank_Estimate", y="UN_Region", data=df, errorbar=None)

plt.show()

# %%
fig = plt.figure(figsize = (8,5))

ax = sns.barplot(x = "IMF_Estimate",  y = "UN_Region",
data = df, errorbar = None)

ax.bar_label(ax.containers[0])

plt.show()

# %%
fig = plt.figure(figsize = (8,5))
ax = sns.barplot(x = "UN_Region",  y = "IMF_Estimate",
                 data = df, errorbar = None)

ax.bar_label(ax.containers[0])


ax.set_title("Regions by IMF Estimate")
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
df.plot(x='UN_Region', y='UN_Estimate', kind='scatter',
        figsize=(10,6),
        title="Scatter Plot")

plt.show()

# %% [markdown]
# ### Boxplot and Outliers

# %% [markdown]
# ![image.png](attachment:da6a7715-3b1c-4165-a2a9-4dc8ca096bd7.png)

# %%
sns.boxplot(x=df["UN_Estimate"])

plt.show()

# %%
df[df["UN_Estimate"]>50000].head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5         0              234316
# 2     Liechtenstein    Europe      163507.5         0              157755
# 3        Luxembourg    Europe      132372.0      2023              133590
# 4           Ireland    Europe      114581.0      2023              100172
# 5           Bermuda  Americas      113371.5         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_27['IMF_Estimate'].plot(kind='hist', bins=20, title='IMF_Estimate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28['IMF_Year'].plot(kind='hist', bins=20, title='IMF_Year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29['WorldBank_Estimate'].plot(kind='hist', bins=20, title='WorldBank_Estimate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_30['WorldBank_Year'].plot(kind='hist', bins=20, title='WorldBank_Year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_31.groupby('Country/Territory').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_32.groupby('UN_Region').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_33.plot(kind='scatter', x='IMF_Estimate', y='IMF_Year', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_34.plot(kind='scatter', x='IMF_Year', y='WorldBank_Estimate', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_35.plot(kind='scatter', x='WorldBank_Estimate', y='WorldBank_Year', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_36.plot(kind='scatter', x='WorldBank_Year', y='UN_Estimate', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_37['IMF_Estimate'].plot(kind='line', figsize=(8, 4), title='IMF_Estimate')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_38['IMF_Year'].plot(kind='line', figsize=(8, 4), title='IMF_Year')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_39['WorldBank_Estimate'].plot(kind='line', figsize=(8, 4), title='WorldBank_Estimate')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_40['WorldBank_Year'].plot(kind='line', figsize=(8, 4), title='WorldBank_Year')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['UN_Region'].value_counts()
#     for x_label, grp in _df_41.groupby('Country/Territory')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Country/Territory')
# _ = plt.ylabel('UN_Region')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_42['Country/Territory'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_42, x='IMF_Estimate', y='Country/Territory', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_43['UN_Region'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_43, x='IMF_Estimate', y='UN_Region', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_44['Country/Territory'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_44, x='IMF_Year', y='Country/Territory', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_45['UN_Region'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_45, x='IMF_Year', y='UN_Region', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
sns.boxplot(x=df["WorldBank_Estimate"])

plt.show()

# %%
sns.boxplot(x=df["IMF_Estimate"])

plt.show()

# %%
df[df["UN_Estimate"]>100000]
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5         0              234316
# 2     Liechtenstein    Europe      163507.5         0              157755
# 3        Luxembourg    Europe      132372.0      2023              133590
# 4           Ireland    Europe      114581.0      2023              100172
# 5           Bermuda  Americas      113371.5         0              114090
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1            2021       234317    2021
# 2            2020       169260    2021
# 3            2021       133745    2021
# 4            2021       101109    2021
# 5            2021       112653    2021

# %%
df.UN_Estimate.mean()
# Out:
# 17767.304932735427

# %%
df.shape
# Out:
# (223, 8)

# %% [markdown]
# ## Create another dataframe called data excluding  5 countries with highest UN estimate

# %%
data = df[-(df["UN_Estimate"]>100000)]

# %%
data.head()
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 6             Norway    Europe      101103.0      2023               89154
# 7        Switzerland    Europe       98767.0      2023               91992
# 8          Singapore      Asia       91100.0      2023               72794
# 9        Isle of Man    Europe       43579.0         0               87158
# 10    Cayman Islands  Americas       85909.5         0               86569
#
#     WorldBank_Year  UN_Estimate UN_Year
# 6             2021        89242    2021
# 7             2021        93525    2021
# 8             2021        66822    2021
# 9             2019            0       0
# 10            2021        85250    2021

# %%
data.shape
# Out:
# (218, 8)

# %%
data.UN_Estimate.mean()
# Out:
# 14729.47247706422

# %%
df.UN_Estimate.mean()
# Out:
# 17767.304932735427

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.boxplot(x=data["UN_Estimate"])
plt.show()

# %% [markdown]
# ## Removing outliers

# %% [markdown]
# ![image.png](attachment:da6a7715-3b1c-4165-a2a9-4dc8ca096bd7.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lower_q = df["UN_Estimate"].quantile(0.25)
lower_q
# Out:
# 2039.0

# %%
higher_q = df["UN_Estimate"].quantile(0.75)
higher_q
# Out:
# 20740.0

# %%
iqr = higher_q - lower_q
iqr
# Out:
# 18701.0

# %%
upper_boundary = higher_q + 1.5 * iqr
upper_boundary
# Out:
# 48791.5

# %%
lower_boundary = lower_q - 1.5 * iqr
lower_boundary
# Out:
# -26012.5

# %%
df_filtered = df[(df["UN_Estimate"] < upper_boundary) & (df["UN_Estimate"] > lower_boundary)]

# %%
df_filtered.head()
# Out:
#        Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 9            Isle of Man    Europe       43579.0         0
# 14       Channel Islands    Europe       37576.5         0
# 15         Faroe Islands    Europe       34505.0         0
# 29                 Macau      Asia       50571.0      2023
# 30  United Arab Emirates      Asia       49451.0      2023
#
#     WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 9                87158            2019            0       0
# 14               75153            2007            0       0
# 15               69010            2021            0       0
# 29               43874            2021        43555    2021
# 30               44316            2021        43295    2021

# %%
df_filtered.shape
# there were 223 rows - 196 = 27 outliers dropped
# Out:
# (196, 8)

# %%
df_filtered.UN_Estimate.mean()
# Out:
# 9415.168367346938

# %%
df.UN_Estimate.mean()
# Out:
# 17767.304932735427

# %%
#how can we create a table with following
df_filtered.WorldBank_Estimate.mean()
# Out:
# 11096.647959183674

# %%
df.WorldBank_Estimate.mean()
# Out:
# 18927.417040358745

# %%
df_filtered.IMF_Estimate.mean()
# Out:
# 11538.908163265307

# %%
df.IMF_Estimate.mean()
# Out:
# 19935.053811659192
